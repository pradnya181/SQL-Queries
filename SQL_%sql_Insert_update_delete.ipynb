# %%
# !pip install sqlalchemy==1.3.9
# !pip install ibm_db_sa
# !pip install ipython-sql
# Out:
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # The SQL INSERT INTO Statement
# The INSERT INTO statement is used to insert new records in a table.
#
# INSERT INTO Syntax
# It is possible to write the INSERT INTO statement in two ways:
#
# 1. Specify both the column names and the values to be inserted:

# %% [raw]
# INSERT INTO table_name (column1, column2, column3, ...)
# VALUES (value1, value2, value3, ...);

# %% [markdown]
# 2. If you are adding values for all the columns of the table, you do not need to specify the column names in the SQL query. However, make sure the order of the values is in the same order as the columns in the table. Here, the INSERT INTO syntax would be as follows:

# %% [raw]
# INSERT INTO table_name
# VALUES (value1, value2, value3, ...);

# %%
import csv, sqlite3

con = sqlite3.connect("new_schema.db")
cur = con.cursor()

# %%
# %reload_ext sql

# %%
# %sql sqlite:///new_schema.db

# %%
import pandas as pd
df = pd.read_csv("C:/Users/I A T Laptop L.L.C/Desktop/JupyterN/Credit.csv")
df.to_sql("cred", con, if_exists='replace', index=False,method="multi")
# Out:
# C:\Users\I A T Laptop L.L.C\anaconda3\lib\site-packages\pandas\core\generic.py:2779: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
# %sql select * from cred
# Out:
#  * sqlite:///new_schema.db
# Done.
# [(1, 1, 14.891, 3606, 283, 2, 34, 11, ' Male', 'No', 'Yes', 'Caucasian', 333),
#  (2, 2, 106.025, 6645, 483, 3, 82, 15, 'Female', 'Yes', 'Yes', 'Asian', 903),
#  (3, 3, 104.593, 7075, 514, 4, 71, 11, ' Male', 'No', 'No', 'Asian', 580),
#  (4, 4, 148.924, 9504, 681, 3, 36, 11, 'Female', 'No', 'No', 'Asian', 964),
#  (5, 5, 55.882, 4897, 357, 2, 68, 16, ' Male', 'No', 'Yes', 'Caucasian', 331),
#  (6, 6, 80.18, 8047, 569, 4, 77, 10, ' Male', 'No', 'No', 'Caucasian', 1151),
#  (7, 7, 20.996, 3388, 259, 2, 37, 12, 'Female', 'No', 'No', 'African American', 203),
#  (8, 8, 71.408, 7114, 512, 2, 87, 9, ' Male', 'No', 'No', 'Asian', 872),
#  (9, 9, 15.125, 3300, 266, 5, 66, 13, 'Female', 'No', 'No', 'Caucasian', 279),
#  (10, 10, 71.061, 6819, 491, 3, 41, 19, 'Female', 'Yes', 'Yes', 'African American', 1350),
#  (11, 11, 63.095, 8117, 589, 4, 30, 14, ' Male', 'No', 'Yes', 'Caucasian', 1407),
# ...

# %%
# %sql INSERT INTO cred values ('140','140','107.841','10384','728','3','87','7','Male','No','No','African American','1597')
# Out:
#  * sqlite:///new_schema.db
# 1 rows affected.
# []

# %%
# %sql select * from cred
# Out:
#  * sqlite:///new_schema.db
# Done.
# [(1, 1, 14.891, 3606, 283, 2, 34, 11, ' Male', 'No', 'Yes', 'Caucasian', 333),
#  (2, 2, 106.025, 6645, 483, 3, 82, 15, 'Female', 'Yes', 'Yes', 'Asian', 903),
#  (3, 3, 104.593, 7075, 514, 4, 71, 11, ' Male', 'No', 'No', 'Asian', 580),
#  (4, 4, 148.924, 9504, 681, 3, 36, 11, 'Female', 'No', 'No', 'Asian', 964),
#  (5, 5, 55.882, 4897, 357, 2, 68, 16, ' Male', 'No', 'Yes', 'Caucasian', 331),
#  (6, 6, 80.18, 8047, 569, 4, 77, 10, ' Male', 'No', 'No', 'Caucasian', 1151),
#  (7, 7, 20.996, 3388, 259, 2, 37, 12, 'Female', 'No', 'No', 'African American', 203),
#  (8, 8, 71.408, 7114, 512, 2, 87, 9, ' Male', 'No', 'No', 'Asian', 872),
#  (9, 9, 15.125, 3300, 266, 5, 66, 13, 'Female', 'No', 'No', 'Caucasian', 279),
#  (10, 10, 71.061, 6819, 491, 3, 41, 19, 'Female', 'Yes', 'Yes', 'African American', 1350),
#  (11, 11, 63.095, 8117, 589, 4, 30, 14, ' Male', 'No', 'Yes', 'Caucasian', 1407),
# ...

# %%
emp = pd.read_csv("C:/Users/I A T Laptop L.L.C/Desktop/JupyterN/emp_2.csv")
emp
# Out:
#    empid      fn        ln     sal  did
# 0    101   Naman     Singh    5000   20
# 1    102   Raman  Tripathi    7000   20
# 2    103  Chaman     Nagor    8000   20
# 3    104   Nisha     Patil    9000   30
# 4    105   Madhu     Reddy   10000   30
# 5    106   Rahul   Barkade  122746  113

# %%
import pandas as pd
emp = pd.read_csv("C:/Users/I A T Laptop L.L.C/Desktop/JupyterN/emp.csv")
emp.to_sql("empl", con, if_exists='replace', index=False,method="multi")
# Out:
# C:\Users\I A T Laptop L.L.C\anaconda3\lib\site-packages\pandas\core\generic.py:2779: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
# %sql select * from empl
# Out:
#  * sqlite:///new_schema.db
# Done.
# [(101, 'Akshay', 4000, 20),
#  (102, 'Yogesh', 5000, 30),
#  (103, 'Payal', 6000, 20),
#  (104, 'Priyanka', 7000, 30),
#  (105, 'Amit', 8000, 40)]

# %%
# %sql INSERT INTO empl values ('107', 'Pradnya', 'Pune', '30000')
# Out:
#  * sqlite:///new_schema.db
# 1 rows affected.
# []

# %%
# %sql select * from empl
# Out:
#  * sqlite:///new_schema.db
# Done.
# [(101, 'Akshay', 4000, 20),
#  (102, 'Yogesh', 5000, 30),
#  (103, 'Payal', 6000, 20),
#  (104, 'Priyanka', 7000, 30),
#  (105, 'Amit', 8000, 40),
#  (107, 'Pradnya', 'Pune', 30000)]

# %% [markdown]
# **********

# %% [markdown]
# # The SQL UPDATE Statement
# The UPDATE statement is used to modify the existing records in a table.

# %% [markdown]
# * Note: Be careful when updating records in a table! Notice the WHERE clause in the UPDATE statement. The WHERE clause specifies which record(s) that should be updated. If you omit the WHERE clause, all records in the table will be updated!

# %% [markdown]
# # Update the  Make column of all records with "BMW" in the A table.

# %% [markdown]
# # UPDATE Syntax
# UPDATE table_name
# SET column1 = value1, column2 = value2, ...
# WHERE condition;

# %%
A = pd.read_csv("C:/Users/I A T Laptop L.L.C/Desktop/JupyterN/Cars93.csv")
A.to_sql("cars", con, if_exists='replace', index=False,method="multi")

# %%
# %sql update cars set Make = 'BMW'
# Out:
#  * sqlite:///new_schema.db
# 93 rows affected.
# []

# %%
B = %sql select * from cars
# Out:
#  * sqlite:///new_schema.db
# Done.

# %%
B
# Out:
# [(1, 'Acura', 'Integra', 'Small', 12.9, 15.9, 18.8, 25, 31, 'None', 'Front', '4', 1.8, 140, 6300, 2890, 'Yes', 13.2, 5, 177, 102, 68, 37, 26.5, 11.0, 2705, 'non-USA', 'BMW'),
#  (2, 'Acura', 'Legend', 'Midsize', 29.2, 33.9, 38.7, 18, 25, 'Driver & Passenger', 'Front', '6', 3.2, 200, 5500, 2335, 'Yes', 18.0, 5, 195, 115, 71, 38, 30.0, 15.0, 3560, 'non-USA', 'BMW'),
#  (3, 'Audi', '90', 'Compact', 25.9, 29.1, 32.3, 20, 26, 'Driver only', 'Front', '6', 2.8, 172, 5500, 2280, 'Yes', 16.9, 5, 180, 102, 67, 37, 28.0, 14.0, 3375, 'non-USA', 'BMW'),
#  (4, 'Audi', '100', 'Midsize', 30.8, 37.7, 44.6, 19, 26, None, 'Front', '6', 2.8, 172, 5500, 2535, 'Yes', 21.1, 6, 193, 106, 70, 37, 31.0, 17.0, 3405, 'non-USA', 'BMW'),
#  (5, 'BMW', '535i', 'Midsize', 23.7, 30.0, 36.2, 22, 30, 'Driver only', 'Rear', '4', 3.5, 208, 5700, 2545, 'Yes', 21.1, 4, 186, 109, 69, 39, 27.0, 13.0, 3640, 'non-USA', 'BMW'),
# ...

# %%
# %sql select Make from cars where Make ='BMW'
# Out:
#  * sqlite:///new_schema.db
# Done.
# [('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
#  ('BMW',),
# ...

# %% [markdown]
# # UPDATE Multiple Records
# It is the WHERE clause that determines how many records will be updated.
#
# The following SQL statement will update the ContactName to "Juan" for all records where country is "Mexico":

# %% [markdown]
# * Be careful when updating records. If you omit the WHERE clause, ALL records will be updated!

# %% [markdown]
# # Que:-Set the value of the Model columns to 'Integra', but only the ones where the AirBags column has the value "None".

# %%
# %sql update cars\
set Model = 'Integra'\
where AirBags = 'None'
# Out:
#  * sqlite:///new_schema.db
# 33 rows affected.
# []

# %%
# %sql select * from cars
# Out:
#  * sqlite:///new_schema.db
# Done.
# [(1, 'Acura', 'Integra', 'Small', 12.9, 15.9, 18.8, 25, 31, 'None', 'Front', '4', 1.8, 140, 6300, 2890, 'Yes', 13.2, 5, 177, 102, 68, 37, 26.5, 11.0, 2705, 'non-USA', 'BMW'),
#  (2, 'Acura', 'Legend', 'Midsize', 29.2, 33.9, 38.7, 18, 25, 'Driver & Passenger', 'Front', '6', 3.2, 200, 5500, 2335, 'Yes', 18.0, 5, 195, 115, 71, 38, 30.0, 15.0, 3560, 'non-USA', 'BMW'),
#  (3, 'Audi', '90', 'Compact', 25.9, 29.1, 32.3, 20, 26, 'Driver only', 'Front', '6', 2.8, 172, 5500, 2280, 'Yes', 16.9, 5, 180, 102, 67, 37, 28.0, 14.0, 3375, 'non-USA', 'BMW'),
#  (4, 'Audi', '100', 'Midsize', 30.8, 37.7, 44.6, 19, 26, None, 'Front', '6', 2.8, 172, 5500, 2535, 'Yes', 21.1, 6, 193, 106, 70, 37, 31.0, 17.0, 3405, 'non-USA', 'BMW'),
#  (5, 'BMW', '535i', 'Midsize', 23.7, 30.0, 36.2, 22, 30, 'Driver only', 'Rear', '4', 3.5, 208, 5700, 2545, 'Yes', 21.1, 4, 186, 109, 69, 39, 27.0, 13.0, 3640, 'non-USA', 'BMW'),
# ...

# %%
# %sql select id,Model,AirBags from cars\
where AirBags = 'None'
# Out:
#  * sqlite:///new_schema.db
# Done.
# [(1, 'Integra', 'None'),
#  (12, 'Integra', 'None'),
#  (15, 'Integra', 'None'),
#  (16, 'Integra', 'None'),
#  (17, 'Integra', 'None'),
#  (23, 'Integra', 'None'),
#  (29, 'Integra', 'None'),
#  (31, 'Integra', 'None'),
#  (32, 'Integra', 'None'),
#  (33, 'Integra', 'None'),
#  (39, 'Integra', 'None'),
#  (44, 'Integra', 'None'),
#  (45, 'Integra', 'None'),
#  (47, 'Integra', 'None'),
#  (53, 'Integra', 'None'),
#  (54, 'Integra', 'None'),
#  (56, 'Integra', 'None'),
#  (61, 'Integra', 'None'),
#  (62, 'Integra', 'None'),
#  (66, 'Integra', 'None'),
#  (68, 'Integra', 'None'),
#  (70, 'Integra', 'None'),
#  (72, 'Integra', 'None'),
#  (73, 'Integra', 'None'),
#  (74, 'Integra', 'None'),
#  (76, 'Integra', 'None'),
#  (80, 'Integra', 'None'),
#  (81, 'Integra', 'None'),
#  (83, 'Integra', 'None'),
#  (88, 'Integra', 'None'),
#  (89, 'Integra', 'None'),
#  (90, 'Integra', 'None'),
#  (91, 'Integra', 'None')]

# %% [markdown]
# # Q:-Update the Model value with century and the Make value to mercedez for 7th id

# %%
# %sql update cars\
set Model = 'century' , Make = 'mercedez'\
where id = 7
# Out:
#  * sqlite:///new_schema.db
# 1 rows affected.
# []

# %%
# %sql select id,Model,Make\
from cars\
where id = 7
# Out:
#  * sqlite:///new_schema.db
# Done.
# [(7, 'century', 'mercedez')]

# %% [markdown]
# # ***DELETE***

# %% [markdown]
# *The DELETE statement is used to delete existing records in a table.

# %% [markdown]
# * Note: Be careful when deleting records in a table! Notice the WHERE clause in the DELETE statement. The WHERE clause specifies which record(s) should be deleted. If you omit the WHERE clause, all records in the table will be deleted!

# %% [markdown]
# # DELETE Syntax
# DELETE FROM table_name WHERE condition;

# %% [markdown]
# # Q:-Delete all the records from the Customers table where the Country value is 'Norway'.

# %%
# %sql delete from cars\
where AirBags = 'None'
# Out:
#  * sqlite:///new_schema.db
# 33 rows affected.
# []

# %%
# %sql select * from cars
# Out:
#  * sqlite:///new_schema.db
# Done.
# [(2, 'Acura', 'Legend', 'Midsize', 29.2, 33.9, 38.7, 18, 25, 'Driver & Passenger', 'Front', '6', 3.2, 200, 5500, 2335, 'Yes', 18.0, 5, 195, 115, 71, 38, 30.0, 15.0, 3560, 'non-USA', 'BMW'),
#  (3, 'Audi', '90', 'Compact', 25.9, 29.1, 32.3, 20, 26, 'Driver only', 'Front', '6', 2.8, 172, 5500, 2280, 'Yes', 16.9, 5, 180, 102, 67, 37, 28.0, 14.0, 3375, 'non-USA', 'BMW'),
#  (4, 'Audi', '100', 'Midsize', 30.8, 37.7, 44.6, 19, 26, None, 'Front', '6', 2.8, 172, 5500, 2535, 'Yes', 21.1, 6, 193, 106, 70, 37, 31.0, 17.0, 3405, 'non-USA', 'BMW'),
#  (5, 'BMW', '535i', 'Midsize', 23.7, 30.0, 36.2, 22, 30, 'Driver only', 'Rear', '4', 3.5, 208, 5700, 2545, 'Yes', 21.1, 4, 186, 109, 69, 39, 27.0, 13.0, 3640, 'non-USA', 'BMW'),
#  (6, 'Buick', 'Century', 'Midsize', 14.2, 15.7, 17.3, 22, 31, 'Driver only', 'Front', '4', 2.2, 110, 5200, 2565, 'No', 16.4, 6, 189, 105, 69, 41, 28.0, 16.0, 2880, 'USA', 'BMW'),
# ...

# %% [markdown]
# # Q:-Delete all the records from the Customers table.

# %%
# %sql delete from cars
# Out:
#  * sqlite:///new_schema.db
# 60 rows affected.
# []

# %%
# %sql select * from cars
# Out:
#  * sqlite:///new_schema.db
# Done.
# []

# %%
# All rows get deleted

# %% [markdown]
# # The SQL MIN() and MAX() Functions
# The MIN() function returns the smallest value of the selected column.
#
# The MAX() function returns the largest value of the selected column.

# %% [raw]
# * MIN() Syntax
#
# SELECT MIN(column_name)
# FROM table_name
# WHERE condition;
#
# * MAX() Syntax
#
# SELECT MAX(column_name)
# FROM table_name
# WHERE condition;

# %% [markdown]
# # Q:- Use the MIN function to select the record with the smallest value of the Price column.

# %%
C = pd.read_csv("C:/Users/I A T Laptop L.L.C/Desktop/JupyterN/Cars93.csv")
C.to_sql("cars9", con, if_exists='replace', index=False,method="multi")

# %%
# %sql SELECT MIN(Price)\
FROM cars9
# Out:
#  * sqlite:///new_schema.db
# Done.
# [(7.4,)]

# %% [markdown]
# # Q:-Use an SQL function to select the record with the highest value of the Price column.

# %%
# %sql SELECT max(Price)\
FROM cars9
# Out:
#  * sqlite:///new_schema.db
# Done.
# [(61.9,)]

# %% [markdown]
# # *** COUNT(), AVG() and SUM() Functions

# %% [markdown]
# # Q:-Use the correct function to return the number of records that have the type value set to small.

# %%
# %sql SELECT count(*)\
FROM cars9\
where Type = 'Small'
# Out:
#  * sqlite:///new_schema.db
# Done.
# [(21,)]

# %% [markdown]
# # Q:-Use an SQL function to calculate the average price of all products.

# %%
# %sql select avg(Price)\
from cars9
# Out:
#  * sqlite:///new_schema.db
# Done.
# [(19.509677419354837,)]

# %% [markdown]
# # Q:-Use an SQL function to calculate the sum of all the Price column values in the Products table.

# %%
# %sql select sum(Price)\
from cars9
# Out:
#  * sqlite:///new_schema.db
# Done.
# [(1814.3999999999999,)]

# %% [markdown]
# # **Like function

# %% [raw]
# The SQL LIKE Operator
# The LIKE operator is used in a WHERE clause to search for a specified pattern in a column.
#
# There are two wildcards often used in conjunction with the LIKE operator:
#
#  *The percent sign (%) represents zero, one, or multiple characters
#  *The underscore sign (_) represents one, single character

# %% [markdown]
# Note: MS Access uses an asterisk (*) instead of the percent sign (%), and a question mark (?) instead of the underscore (_).

# %% [markdown]
# * Tip: You can also combine any number of conditions using AND or OR operators.

# %% [markdown]
# # LIKE Syntax
# SELECT column1, column2, ...
# FROM table_name
# WHERE columnN LIKE pattern;

# %%
df = pd.read_csv("C:/Users/I A T Laptop L.L.C/Desktop/JupyterN/hitters.csv")
df.to_sql("hitt", con, if_exists='replace', index=False,method="multi")

# %%
df
# Out:
#                  Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0       Andy Allanson    293    66      1    30   29     14      1     293
# 1          Alan Ashby    315    81      7    24   38     39     14    3449
# 2         Alvin Davis    479   130     18    66   72     76      3    1624
# 3        Andre Dawson    496   141     20    65   78     37     11    5628
# 4    Andres Galarraga    321    87     10    39   42     30      2     396
# ..                ...    ...   ...    ...   ...  ...    ...    ...     ...
# 317      Willie McGee    497   127      7    65   48     37      5    2703
# 318   Willie Randolph    492   136      5    76   50     94     12    5511
# 319    Wayne Tolleson    475   126      3    61   43     52      6    1700
# 320     Willie Upshaw    573   144      9    85   60     78      8    3198
# 321     Willie Wilson    631   170      9    77   44     31     11    4908
#
# ...

# %% [markdown]
# Here are some examples showing different LIKE operators with '%' and '_' wildcards:

# %% [raw]
# LIKE Operator	Description
# WHERE CustomerName LIKE 'a%'	Finds any values that start with "a"
# WHERE CustomerName LIKE '%a'	Finds any values that end with "a"
# WHERE CustomerName LIKE '%or%'	Finds any values that have "or" in any position
# WHERE CustomerName LIKE '_r%'	Finds any values that have "r" in the second position
# WHERE CustomerName LIKE 'a_%'	Finds any values that start with "a" and are at least 2 characters in length
# WHERE CustomerName LIKE 'a__%'	Finds any values that start with "a" and are at least 3 characters in length
# WHERE ContactName LIKE 'a%o'	Finds any values that start with "a" and ends with "o"
