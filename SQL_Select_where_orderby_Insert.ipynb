# %% [markdown]
# # The SQL SELECT DISTINCT Statement

# %%
import pandasql
from pandasql import sqldf
import pandas as pd

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
A = pd.read_csv("C:/Users/I A T Laptop L.L.C/Desktop/JupyterN/Credit.csv")
A
# Out:
#      Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1    1   14.891   3606     283      2   34         11    Male
# 1             2    2  106.025   6645     483      3   82         15  Female
# 2             3    3  104.593   7075     514      4   71         11    Male
# 3             4    4  148.924   9504     681      3   36         11  Female
# 4             5    5   55.882   4897     357      2   68         16    Male
# ..          ...  ...      ...    ...     ...    ...  ...        ...     ...
# 395         396  396   12.096   4100     307      3   32         13    Male
# 396         397  397   13.364   3838     296      5   65         17    Male
# 397         398  398   57.872   4171     321      5   67         12  Female
# 398         399  399   37.728   2525     192      1   44         13    Male
# 399         400  400   18.701   5524     415      5   64          7  Female
#
#     Student Married         Ethnicity  Balance
# ...

# %% [raw]
# The SELECT DISTINCT statement is used to return only distinct (different) values.
#
# Inside a table, a column often contains many duplicate values; and sometimes you only want to list the different (distinct) values.

# %% [raw]
# SELECT DISTINCT column1, column2, ...
# FROM table_name;

# %%
sqldf("select * from A")
# Out:
#      Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1    1   14.891   3606     283      2   34         11    Male
# 1             2    2  106.025   6645     483      3   82         15  Female
# 2             3    3  104.593   7075     514      4   71         11    Male
# 3             4    4  148.924   9504     681      3   36         11  Female
# 4             5    5   55.882   4897     357      2   68         16    Male
# ..          ...  ...      ...    ...     ...    ...  ...        ...     ...
# 395         396  396   12.096   4100     307      3   32         13    Male
# 396         397  397   13.364   3838     296      5   65         17    Male
# 397         398  398   57.872   4171     321      5   67         12  Female
# 398         399  399   37.728   2525     192      1   44         13    Male
# 399         400  400   18.701   5524     415      5   64          7  Female
#
#     Student Married         Ethnicity  Balance
# ...

# %%
sqldf("select Education from A") # All columns
# Out:
#      Education
# 0           11
# 1           15
# 2           11
# 3           11
# 4           16
# ..         ...
# 395         13
# 396         17
# 397         12
# 398         13
# 399          7
#
# [400 rows x 1 columns]

# %% [markdown]
# # find distinct values of Education column

# %%
sqldf("select distinct Education from A") # showing only dictinct results
# Out:
#     Education
# 0          11
# 1          15
# 2          16
# 3          10
# 4          12
# 5           9
# 6          13
# 7          19
# 8          14
# 9           7
# 10         17
# 11          8
# 12          5
# 13         20
# 14         18
# 15          6

# %% [markdown]
# # find count of distinct values of Education column

# %%
sqldf("select COUNT(DISTINCT Education) FROM A")
# Out:
#    COUNT(DISTINCT Education)
# 0                         16

# %% [markdown]
# # *** WHERE clause***

# %% [raw]
# SELECT column1, column2, ...
# FROM table_name
# WHERE condition;

# %% [raw]
# ***The WHERE clause is not only used in SELECT statements, it is also used in UPDATE, DELETE, etc.!***

# %% [markdown]
# # Solved Examples on where clause

# %% [markdown]
# # select all columns from table where Ethnicity is Asian

# %%
sqldf("select * from A where Ethnicity='Asian'")
# Out:
#      Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             2    2  106.025   6645     483      3   82         15  Female
# 1             3    3  104.593   7075     514      4   71         11    Male
# 2             4    4  148.924   9504     681      3   36         11  Female
# 3             8    8   71.408   7114     512      2   87          9    Male
# 4            13   13   80.616   5308     394      1   57          7  Female
# ..          ...  ...      ...    ...     ...    ...  ...        ...     ...
# 97          386  386   26.400   5640     398      3   58         15  Female
# 98          388  388   16.529   1357     126      3   62          9    Male
# 99          391  391  135.118  10578     747      3   81         15  Female
# 100         393  393   25.974   2308     196      2   24         10    Male
# 101         400  400   18.701   5524     415      5   64          7  Female
#
#     Student Married Ethnicity  Balance
# ...

# %% [markdown]
# # select data from table where Age is greater than 50

# %%
sqldf("select * from A where Age > 50")
# Out:
#      Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             2    2  106.025   6645     483      3   82         15  Female
# 1             3    3  104.593   7075     514      4   71         11    Male
# 2             5    5   55.882   4897     357      2   68         16    Male
# 3             6    6   80.180   8047     569      4   77         10    Male
# 4             8    8   71.408   7114     512      2   87          9    Male
# ..          ...  ...      ...    ...     ...    ...  ...        ...     ...
# 222         391  391  135.118  10578     747      3   81         15  Female
# 223         394  394   17.316   1335     138      2   65         13    Male
# 224         397  397   13.364   3838     296      5   65         17    Male
# 225         398  398   57.872   4171     321      5   67         12  Female
# 226         400  400   18.701   5524     415      5   64          7  Female
#
#     Student Married         Ethnicity  Balance
# ...

# %% [markdown]
# # select all columns from table where Ethnicity is not Asian

# %% [markdown]
# # ** NOT**

# %%
sqldf("select * from A where not Ethnicity ='Asian'")
# Out:
#      Unnamed: 0   ID  Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1    1  14.891   3606     283      2   34         11    Male
# 1             5    5  55.882   4897     357      2   68         16    Male
# 2             6    6  80.180   8047     569      4   77         10    Male
# 3             7    7  20.996   3388     259      2   37         12  Female
# 4             9    9  15.125   3300     266      5   66         13  Female
# ..          ...  ...     ...    ...     ...    ...  ...        ...     ...
# 293         395  395  49.794   5758     410      4   40          8    Male
# 294         396  396  12.096   4100     307      3   32         13    Male
# 295         397  397  13.364   3838     296      5   65         17    Male
# 296         398  398  57.872   4171     321      5   67         12  Female
# 297         399  399  37.728   2525     192      1   44         13    Male
#
#     Student Married         Ethnicity  Balance
# ...

# %% [markdown]
# # Select all records where the Cards column has the value 5.

# %%
sqldf("select * from A where Cards = 5")
# Out:
#     Unnamed: 0   ID  Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0            9    9  15.125   3300     266      5   66         13  Female
# 1           24   24  64.027   5179     398      5   48          8    Male
# 2           26   26  14.090   4323     326      5   25         16  Female
# 3           32   32  28.941   2733     210      5   43         16    Male
# 4           96   96  14.084    855     120      5   46         17  Female
# 5          100  100  83.851   8494     607      5   47         18    Male
# 6          110  110  13.561   3261     279      5   37         19    Male
# 7          116  116  40.442   4828     369      5   81          8  Female
# 8          127  127  26.427   5533     433      5   50         15  Female
# 9          132  132  10.726   1568     162      5   46         19    Male
# 10         150  150  13.444    886     121      5   44         10    Male
# 11         157  157  31.811   4284     338      5   75         13  Female
# ...

# %% [markdown]
# # Select all records where the Ethnicity column has the value 'Asian' and the Education column has the value 10.

# %%
sqldf("select * from A where Ethnicity ='Asian' AND Education = 10")
# Out:
#    Unnamed: 0   ID  Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0          54   54  16.304   5466     413      4   66         10    Male
# 1         150  150  13.444    886     121      5   44         10    Male
# 2         219  219  10.627   1647     149      2   71         10  Female
# 3         345  345  48.218   5199     401      7   39         10    Male
# 4         393  393  25.974   2308     196      2   24         10    Male
#
#   Student Married Ethnicity  Balance
# 0      No     Yes     Asian      957
# 1      No     Yes     Asian        0
# 2     Yes     Yes     Asian      195
# 3      No     Yes     Asian      633
# 4      No      No     Asian        0

# %% [markdown]
# # Select all records where the Ethnicity column has the value 'Asian' or Caucasian

# %%
sqldf("select * from A where Ethnicity ='Asian' or Ethnicity ='Caucasian'")
# Out:
#      Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1    1   14.891   3606     283      2   34         11    Male
# 1             2    2  106.025   6645     483      3   82         15  Female
# 2             3    3  104.593   7075     514      4   71         11    Male
# 3             4    4  148.924   9504     681      3   36         11  Female
# 4             5    5   55.882   4897     357      2   68         16    Male
# ..          ...  ...      ...    ...     ...    ...  ...        ...     ...
# 296         395  395   49.794   5758     410      4   40          8    Male
# 297         396  396   12.096   4100     307      3   32         13    Male
# 298         398  398   57.872   4171     321      5   67         12  Female
# 299         399  399   37.728   2525     192      1   44         13    Male
# 300         400  400   18.701   5524     415      5   64          7  Female
#
#     Student Married  Ethnicity  Balance
# ...

# %% [markdown]
# # **** ORDER BY*****

# %% [raw]
# The ORDER BY keyword is used to sort the result-set in ascending or descending order.
#
# The ORDER BY keyword sorts the records in ascending order by default. To sort the records in descending order, use the DESC keyword.

# %% [markdown]
# # Syntax
# SELECT column1, column2, ...
# FROM table_name
# ORDER BY column1, column2, ... ASC|DESC;

# %%
sqldf("select * from A order by Ethnicity")
# Out:
#      Unnamed: 0   ID  Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             7    7  20.996   3388     259      2   37         12  Female
# 1            10   10  71.061   6819     491      3   41         19  Female
# 2            15   15  19.144   3291     269      2   75         13  Female
# 3            16   16  20.089   2525     200      3   57         15  Female
# 4            17   17  53.598   3714     286      3   73         17  Female
# ..          ...  ...     ...    ...     ...    ...  ...        ...     ...
# 395         392  392  73.327   6555     472      2   43         15  Female
# 396         395  395  49.794   5758     410      4   40          8    Male
# 397         396  396  12.096   4100     307      3   32         13    Male
# 398         398  398  57.872   4171     321      5   67         12  Female
# 399         399  399  37.728   2525     192      1   44         13    Male
#
#     Student Married         Ethnicity  Balance
# ...

# %%
sqldf("select * from A order by Ethnicity desc")
# Out:
#      Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1    1   14.891   3606     283      2   34         11    Male
# 1             5    5   55.882   4897     357      2   68         16    Male
# 2             6    6   80.180   8047     569      4   77         10    Male
# 3             9    9   15.125   3300     266      5   66         13  Female
# 4            11   11   63.095   8117     589      4   30         14    Male
# ..          ...  ...      ...    ...     ...    ...  ...        ...     ...
# 395         381  381  115.123   7760     538      3   83         14  Female
# 396         385  385   20.088   1870     180      3   76         16    Male
# 397         387  387   19.253   3683     287      4   57         10    Male
# 398         394  394   17.316   1335     138      2   65         13    Male
# 399         397  397   13.364   3838     296      5   65         17    Male
#
#     Student Married         Ethnicity  Balance
# ...

# %%
sqldf("select * from A order by Education,Income")
# Out:
#      Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0            31   31   34.142   5666     413      4   47          5  Female
# 1           285  285   14.711   2047     167      2   67          6    Male
# 2           309  309   14.956   4640     332      2   33          6    Male
# 3           255  255   36.508   6386     469      4   79          6  Female
# 4           369  369   89.000   5759     440      3   37          6  Female
# ..          ...  ...      ...    ...     ...    ...  ...        ...     ...
# 395         216  216   41.025   4229     337      3   79         19  Female
# 396          10   10   71.061   6819     491      3   41         19  Female
# 397         194  194  130.209  10088     730      7   39         19  Female
# 398          61   61   35.510   5198     364      2   35         20  Female
# 399          52   52   39.705   3969     301      2   27         20    Male
#
#     Student Married         Ethnicity  Balance
# ...

# %%
sqldf("select *  from A order by Education,Income")
# Out:
#      Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0            31   31   34.142   5666     413      4   47          5  Female
# 1           285  285   14.711   2047     167      2   67          6    Male
# 2           309  309   14.956   4640     332      2   33          6    Male
# 3           255  255   36.508   6386     469      4   79          6  Female
# 4           369  369   89.000   5759     440      3   37          6  Female
# ..          ...  ...      ...    ...     ...    ...  ...        ...     ...
# 395         216  216   41.025   4229     337      3   79         19  Female
# 396          10   10   71.061   6819     491      3   41         19  Female
# 397         194  194  130.209  10088     730      7   39         19  Female
# 398          61   61   35.510   5198     364      2   35         20  Female
# 399          52   52   39.705   3969     301      2   27         20    Male
#
#     Student Married         Ethnicity  Balance
# ...

# %%
sqldf("select Education,Income from A order by Education,Income")
# Out:
#      Education   Income
# 0            5   34.142
# 1            6   14.711
# 2            6   14.956
# 3            6   36.508
# 4            6   89.000
# ..         ...      ...
# 395         19   41.025
# 396         19   71.061
# 397         19  130.209
# 398         20   35.510
# 399         20   39.705
#
# [400 rows x 2 columns]

# %%
sqldf("SELECT * FROM A ORDER BY Ethnicity ASC, Education ASC")
# Out:
#      Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0           140  140  107.841  10384     728      3   87          7    Male
# 1            24   24   64.027   5179     398      5   48          8    Male
# 2            89   89   15.560   4307     352      4   57          8    Male
# 3           116  116   40.442   4828     369      5   81          8  Female
# 4           137  137   54.663   4116     314      2   70          8  Female
# ..          ...  ...      ...    ...     ...    ...  ...        ...     ...
# 395         194  194  130.209  10088     730      7   39         19  Female
# 396         216  216   41.025   4229     337      3   79         19  Female
# 397         239  239   26.532   2910     236      6   58         19  Female
# 398         248  248   36.364   2220     188      3   50         19    Male
# 399         379  379   19.349   4941     366      1   33         19    Male
#
#     Student Married         Ethnicity  Balance
# ...

# %% [markdown]
# # EXERCISE on Order by

# %% [markdown]
# # Select all records from the table, sort the result reversed alphabetically by the column Ethnicity.

# %%
sqldf("select * from A order by Ethnicity desc")
# Out:
#      Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1    1   14.891   3606     283      2   34         11    Male
# 1             5    5   55.882   4897     357      2   68         16    Male
# 2             6    6   80.180   8047     569      4   77         10    Male
# 3             9    9   15.125   3300     266      5   66         13  Female
# 4            11   11   63.095   8117     589      4   30         14    Male
# ..          ...  ...      ...    ...     ...    ...  ...        ...     ...
# 395         381  381  115.123   7760     538      3   83         14  Female
# 396         385  385   20.088   1870     180      3   76         16    Male
# 397         387  387   19.253   3683     287      4   57         10    Male
# 398         394  394   17.316   1335     138      2   65         13    Male
# 399         397  397   13.364   3838     296      5   65         17    Male
#
#     Student Married         Ethnicity  Balance
# ...

# %% [markdown]
# # Select all records from the  table, sort the result alphabetically, first by the column Ethnicity, then, by the column Age.

# %%
sqldf("select * from A order by Ethnicity, Age")
# Out:
#      Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0            26   26   14.090   4323     326      5   25         16  Female
# 1           236  236   10.503   2923     232      3   25         18  Female
# 2            94   94   16.479   5435     388      2   26         16    Male
# 3            52   52   39.705   3969     301      2   27         20    Male
# 4            76   76   33.017   3180     224      2   28         16    Male
# ..          ...  ...      ...    ...     ...    ...  ...        ...     ...
# 395         380  380   53.308   2860     214      1   84         10    Male
# 396         382  382  101.788   8029     574      2   84         11    Male
# 397         190  190   58.351   4411     326      2   85         16  Female
# 398         267  267   88.830   4952     360      4   86         16  Female
# 399         324  324  182.728  13913     982      4   98         17    Male
#
#     Student Married         Ethnicity  Balance
# ...

# %% [markdown]
# # Select all records from the table, sort the result Numericaly by the Age.

# %%
sqldf("select * from A order by Age asc")
# Out:
#      Unnamed: 0   ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0           336  336   24.314   3409     270      2   23          7  Female
# 1            44   44   36.929   6257     445      1   24         14  Female
# 2           153  153   41.419   2120     184      4   24         11  Female
# 3           393  393   25.974   2308     196      2   24         10    Male
# 4            26   26   14.090   4323     326      5   25         16  Female
# ..          ...  ...      ...    ...     ...    ...  ...        ...     ...
# 395           8    8   71.408   7114     512      2   87          9    Male
# 396         140  140  107.841  10384     728      3   87          7    Male
# 397         129  129  123.299   8376     610      2   89         17    Male
# 398         210  210  151.947   9156     642      2   91         11  Female
# 399         324  324  182.728  13913     982      4   98         17    Male
#
#     Student Married         Ethnicity  Balance
# ...

# %% [markdown]
# # The SQL INSERT INTO Statement

# %% [markdown]
# # The SQL INSERT INTO Statement
# The INSERT INTO statement is used to insert new records in a table.
#
# INSERT INTO Syntax
# It is possible to write the INSERT INTO statement in two ways:
#
# 1. Specify both the column names and the values to be inserted:

# %% [raw]
# INSERT INTO table_name (column1, column2, column3, ...)
# VALUES (value1, value2, value3, ...);

# %% [markdown]
# 2. If you are adding values for all the columns of the table, you do not need to specify the column names in the SQL query. However, make sure the order of the values is in the same order as the columns in the table. Here, the INSERT INTO syntax would be as follows:

# %% [raw]
# INSERT INTO table_name
# VALUES (value1, value2, value3, ...);

# %%
import csv, sqlite3

con = sqlite3.connect("my_db1.db")
cur = con.cursor()

# %%
# %sql sqlite:///my_db1.db

# %%
import pandas as pd
df = pd.read_csv("C:/Users/I A T Laptop L.L.C/Desktop/JupyterN/Credit.csv")
df.to_sql("cred", con, if_exists='replace', index=False,method="multi")

# %%
# %sql select * from cred
# Out:
#  * sqlite:///my_db1.db
#    sqlite:///new_schema.db
# Done.
# [(1, 1, 14.891, 3606, 283, 2, 34, 11, ' Male', 'No', 'Yes', 'Caucasian', 333),
#  (2, 2, 106.025, 6645, 483, 3, 82, 15, 'Female', 'Yes', 'Yes', 'Asian', 903),
#  (3, 3, 104.593, 7075, 514, 4, 71, 11, ' Male', 'No', 'No', 'Asian', 580),
#  (4, 4, 148.924, 9504, 681, 3, 36, 11, 'Female', 'No', 'No', 'Asian', 964),
#  (5, 5, 55.882, 4897, 357, 2, 68, 16, ' Male', 'No', 'Yes', 'Caucasian', 331),
#  (6, 6, 80.18, 8047, 569, 4, 77, 10, ' Male', 'No', 'No', 'Caucasian', 1151),
#  (7, 7, 20.996, 3388, 259, 2, 37, 12, 'Female', 'No', 'No', 'African American', 203),
#  (8, 8, 71.408, 7114, 512, 2, 87, 9, ' Male', 'No', 'No', 'Asian', 872),
#  (9, 9, 15.125, 3300, 266, 5, 66, 13, 'Female', 'No', 'No', 'Caucasian', 279),
#  (10, 10, 71.061, 6819, 491, 3, 41, 19, 'Female', 'Yes', 'Yes', 'African American', 1350),
#  (11, 11, 63.095, 8117, 589, 4, 30, 14, ' Male', 'No', 'Yes', 'Caucasian', 1407),
# ...

# %%
# %sql INSERT INTO cred values ('140','140','107.841','10384','728','3','87','7','Male','No','No','African American','1597')
# Out:
#  * sqlite:///my_db1.db
#    sqlite:///new_schema.db
# 1 rows affected.
# []

# %%
# %sql select * from cred
# Out:
#  * sqlite:///my_db1.db
#    sqlite:///new_schema.db
# Done.
# [(1, 1, 14.891, 3606, 283, 2, 34, 11, ' Male', 'No', 'Yes', 'Caucasian', 333),
#  (2, 2, 106.025, 6645, 483, 3, 82, 15, 'Female', 'Yes', 'Yes', 'Asian', 903),
#  (3, 3, 104.593, 7075, 514, 4, 71, 11, ' Male', 'No', 'No', 'Asian', 580),
#  (4, 4, 148.924, 9504, 681, 3, 36, 11, 'Female', 'No', 'No', 'Asian', 964),
#  (5, 5, 55.882, 4897, 357, 2, 68, 16, ' Male', 'No', 'Yes', 'Caucasian', 331),
#  (6, 6, 80.18, 8047, 569, 4, 77, 10, ' Male', 'No', 'No', 'Caucasian', 1151),
#  (7, 7, 20.996, 3388, 259, 2, 37, 12, 'Female', 'No', 'No', 'African American', 203),
#  (8, 8, 71.408, 7114, 512, 2, 87, 9, ' Male', 'No', 'No', 'Asian', 872),
#  (9, 9, 15.125, 3300, 266, 5, 66, 13, 'Female', 'No', 'No', 'Caucasian', 279),
#  (10, 10, 71.061, 6819, 491, 3, 41, 19, 'Female', 'Yes', 'Yes', 'African American', 1350),
#  (11, 11, 63.095, 8117, 589, 4, 30, 14, ' Male', 'No', 'Yes', 'Caucasian', 1407),
# ...
